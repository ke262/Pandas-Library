# %%
import pandas as pd

# %%
pip install chardet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#     Unnamed: 0               Actor                      Film  Year  \
# 0          NaN      Shah Rukh Khan                   Pathaan  2023
# 1          NaN         Salman Khan           Tiger Zinda Hai  2017
# 2          NaN          Aamir Khan                    Dangal  2016
# 3          NaN       Ranbir Kapoor                Brahmastra  2022
# 4          NaN       Ranveer Singh                 Padmaavat  2018
# 5          NaN  Ayushmann Khurrana                 Andhadhun  2018
# 6          NaN       Rajkummar Rao                     Stree  2018
# 7          NaN      Hrithik Roshan                       War  2019
# 8          NaN        Akshay Kumar                Good Newwz  2019
# 9          NaN       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10         NaN        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11         NaN       Vicky Kaushal  Uri: The Surgical Strike  2019
#
#               Genre  BoxOffice(INR Crore)  IMDb
# ...

# %%
df['Actor'][3]
# Out:
# 'Ranbir Kapoor'

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
df[['Actor', 'IMDb']]
# Out:
#                  Actor  IMDb
# 0       Shah Rukh Khan   7.2
# 1          Salman Khan   6.4
# 2           Aamir Khan   8.4
# 3        Ranbir Kapoor   5.6
# 4        Ranveer Singh   7.0
# 5   Ayushmann Khurrana   8.3
# 6        Rajkummar Rao   7.5
# 7       Hrithik Roshan   6.5
# 8         Akshay Kumar   7.0
# 9        Kartik Aaryan   5.9
# 10        Varun Dhawan   6.1
# 11       Vicky Kaushal   8.2

# %%
df.loc[1]
# Out:
# Unnamed: 0                          NaN
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.4
# Name: 1, dtype: object

# %%
df.iloc[1]
# Out:
# Unnamed: 0                          NaN
# Actor                       Salman Khan
# Film                    Tiger Zinda Hai
# Year                               2017
# Genre                            Action
# BoxOffice(INR Crore)                565
# IMDb                                6.4
# Name: 1, dtype: object

# %%
df.loc[8, 'IMDb']
# Out:
# np.float64(7.0)

# %%
df.iloc[7, 5]
# Out:
# np.int64(475)

# %%
df.loc[0:2, ["Actor", "IMDb"]]
# Out:
#             Actor  IMDb
# 0  Shah Rukh Khan   7.2
# 1     Salman Khan   6.4
# 2      Aamir Khan   8.4

# %%
df.iloc[0:2, 0:2]
# Out:
#    Unnamed: 0           Actor
# 0         NaN  Shah Rukh Khan
# 1         NaN     Salman Khan

# %%
df.at[0, "Actor"]
# Out:
# 'Shah Rukh Khan'

# %%
df.iat[0, 1]
# Out:
# 'Shah Rukh Khan'

# %%
df[df['IMDb']>6] ['Actor']
# Out:
#     Unnamed: 0               Actor                      Film  Year  \
# 0          NaN      Shah Rukh Khan                   Pathaan  2023
# 1          NaN         Salman Khan           Tiger Zinda Hai  2017
# 2          NaN          Aamir Khan                    Dangal  2016
# 4          NaN       Ranveer Singh                 Padmaavat  2018
# 5          NaN  Ayushmann Khurrana                 Andhadhun  2018
# 6          NaN       Rajkummar Rao                     Stree  2018
# 7          NaN      Hrithik Roshan                       War  2019
# 8          NaN        Akshay Kumar                Good Newwz  2019
# 10         NaN        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11         NaN       Vicky Kaushal  Uri: The Surgical Strike  2019
#
#               Genre  BoxOffice(INR Crore)  IMDb
# 0            Action                  1050   7.2
# 1            Action                   565   6.4
# 2         Biography                  2024   8.4
# ...

# %%
df[(df['IMDb']>6) | (df['Year']>2018)]
# Out:
#     Unnamed: 0               Actor                      Film  Year  \
# 0          NaN      Shah Rukh Khan                   Pathaan  2023
# 1          NaN         Salman Khan           Tiger Zinda Hai  2017
# 2          NaN          Aamir Khan                    Dangal  2016
# 3          NaN       Ranbir Kapoor                Brahmastra  2022
# 4          NaN       Ranveer Singh                 Padmaavat  2018
# 5          NaN  Ayushmann Khurrana                 Andhadhun  2018
# 6          NaN       Rajkummar Rao                     Stree  2018
# 7          NaN      Hrithik Roshan                       War  2019
# 8          NaN        Akshay Kumar                Good Newwz  2019
# 9          NaN       Kartik Aaryan         Bhool Bhulaiyaa 2  2022
# 10         NaN        Varun Dhawan     Badrinath Ki Dulhania  2017
# 11         NaN       Vicky Kaushal  Uri: The Surgical Strike  2019
#
#               Genre  BoxOffice(INR Crore)  IMDb
# ...

# %%
df.query("Year > 2018 and IMDb >6")
# Out:
#     Unnamed: 0           Actor                      Film  Year   Genre  \
# 0          NaN  Shah Rukh Khan                   Pathaan  2023  Action
# 7          NaN  Hrithik Roshan                       War  2019  Action
# 8          NaN    Akshay Kumar                Good Newwz  2019  Comedy
# 11         NaN   Vicky Kaushal  Uri: The Surgical Strike  2019  Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 7                    475   6.5
# 8                    318   7.0
# 11                   342   8.2
